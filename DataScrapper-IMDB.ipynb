# %%
#COPIED FOR LEARNING
#ORIGINAL CODE IS WRITTEN BELLOW

from bs4 import BeautifulSoup
import requests
import re

url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []


for index in range(0, len(movies)):

    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# 3 - The Godfather: Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# 4 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# 9 - Il buono, il brutto, il cattivo (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach
# ...

# %%
from imdb import IMDb

ia=IMDb()
m = ia.search_movie('3 idiots')
print(m[0]['year'])
print (m[0].movieID)
# Out:
# 2009
# 1187043

# %%
x=ia.get_movie(m[0].movieID)

print (x['cover url'])
# Out:
# https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX101_CR0,0,101,150_.jpg

# %%
import pandas


col_list = ["Movie_Name"]
df = pd.read_csv("ContentFilteringResults.csv", usecols=col_list)

Movie_Name=df["Movie_Name"]

Movie)
l=[]
# Movie_name
# for index in range(0, len(Movie_Name)):
#     searchedMovie=ia.search_movie(Movie_Name[index])
#     getID=ia.get_movie(searchedMovie[0].movieID)
#     l.append(getID['cover url'])
# l
# Out:
# https://m.media-amazon.com/images/M/MV5BNzliZjhkODctMGJjOS00YWQ3LWEzMjgtYmZjNzMwMDYwYWNjXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY150_CR2,0,101,150_.jpg
# https://m.media-amazon.com/images/M/MV5BNjU0ODM1MjExOF5BMl5BanBnXkFtZTcwNDY0ODcyMg@@._V1_SY150_CR2,0,101,150_.jpg
# https://m.media-amazon.com/images/M/MV5BZDczYjU4MDMtY2RjMy00Y2UyLWE2MmMtZjliYWUwNzQ3YjExXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY150_CR0,0,101,150_.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-38b061502912> in <module>
#      12 for index in Movie_name:
#      13     searchedMovie=ia.search_movie(index)
# ---> 14     getID=ia.get_movie(searchedMovie[0].movieID)
#      15     print(getID['cover url'])
#      16 f.close()
#
# ~\anaconda3\lib\site-packages\imdb\__init__.py in get_movie(self, movieID, info, modFunct)
#     415         if modFunct is not None:
# ...

# %%
import csv

f = open ("ContentFilteringResults.csv","r")
with open("ContentFilteringResults.csv", "w") as output:
    for line in f :
       c.writerows(line)

# %%
index=0


f= open("key.txt","w+")
f.write(str(0))
f.close()
# Out:
# 0

# %%
import pandas
import csv


col_list = ["Movie_Name"]
df = pd.read_csv("MovieName.csv", usecols=col_list)

Movie_name=df["Movie_Name"]
##Movie_name=list(Movie_name)
print(len(Movie_name))
f= open("final2.csv","w+")
for index in range(595,len(Movie_name)):
    searchedMovie=ia.search_movie(Movie_name[index])

    getID=ia.get_movie(searchedMovie[0].movieID)
    print (getID)

    getRating=7
    print(getID['cover url'])
    with open('URLs.csv', 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([getID['cover url']])
f.close()
# f2.close()
# Out:
# 789
# Kicking & Screaming
# https://m.media-amazon.com/images/M/MV5BMTA5Njk1MjEzMzZeQTJeQWpwZ15BbWU3MDY3NjY4MjE@._V1_SY150_CR0,0,101,150_.jpg
# Mortal Kombat
# https://m.media-amazon.com/images/M/MV5BY2VkZTcxM2QtMTYyNi00YzA5LTlmMWMtNDYzOTIxMzQ2MjczXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SY150_CR0,0,101,150_.jpg
# RoboCop 3
# https://m.media-amazon.com/images/M/MV5BNzdiMTkwYWUtM2RlYi00NThlLWI5OWYtY2Y3ZjY1MDg5OTMyXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SY150_CR0,0,101,150_.jpg
# Billy Madison
# https://m.media-amazon.com/images/M/MV5BMzcyMjZmNjctNGNhMS00ZmQxLWFkNzQtYTIxYjVkYmU1NmNmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX101_CR0,0,101,150_.jpg
# Hot Shots! Part Deux
# https://m.media-amazon.com/images/M/MV5BZjU2ODlmZWMtODEwZS00NTQ0LTk1ZDYtYzk0ZjE3ZGZhMGM0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX101_CR0,0,101,150_.jpg
# Bad Boys
# https://m.media-amazon.com/images/M/MV5BMGE1ZTQ0ZTEtZTEwZS00NWE0LTlmMDUtMTE1ZWJiZTYzZTQ2XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY150_CR0,0,101,150_.jpg
# A Good Man in Africa
# ...

# %%
import pandas as pd

# Read the files into two dataframes.
df1 = pd.read_csv('IDMerger.csv')
df2 = pd.read_csv('ContentFilteringResults (1).csv')

# Merge the two dataframes, using _ID column as key
df3 = pd.merge(df2, df1, on = 'Movie_Id')
df3.set_index('Movie_Id', inplace = True)

# Write it to a new CSV file
df3.to_csv('URLMerger.csv')

# %%
df1
# Out:
#                 Movie_Name                                            getURLs  \
# 0            A Close Shave  https://m.media-amazon.com/images/M/MV5BNzliZj...
# 1         Gumby: The Movie  https://m.media-amazon.com/images/M/MV5BNjU0OD...
# 2            A Goofy Movie  https://m.media-amazon.com/images/M/MV5BZDczYj...
# 3             House Arrest  https://m.media-amazon.com/images/M/MV5BYWJiMG...
# 4         The Santa Clause  https://m.media-amazon.com/images/M/MV5BMTZlNz...
# ..                     ...                                                ...
# 804  Swiss Family Robinson  https://m.media-amazon.com/images/M/MV5BZDNkMj...
# 805        The Parent Trap  https://m.media-amazon.com/images/M/MV5BNWYyMz...
# 806         The Shaggy Dog  https://m.media-amazon.com/images/M/MV5BMTY0Nz...
# 807          Paris, France  https://m.media-amazon.com/images/M/MV5BMTgyNz...
# 808       Cutthroat Island  https://m.media-amazon.com/images/M/MV5BMDg2YT...
#
#      Movie_Id
# 0         532
# ...

# %%
df2.insert(3,"Urls",df1['getURLs'],True)

# %%
df2.to_csv('URLMerger.csv')
